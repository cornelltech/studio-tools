# %%
import csv
from io import StringIO
from urllib.request import urlopen

# %%
STUDENT_CSV = "startup-ideas-2018.csv"
ALL_STUDENTS = []
SKIP_SECTION_MIX = False
SKIP_MBA_MIX = False
SECTIONS = ['Section 1', 'Section 2', 'Section 3']

csv_reader = csv.reader(open(STUDENT_CSV))
next(csv_reader)
for student in csv_reader:
    (last_name, first_name, email, program, section) = student
    ALL_STUDENTS.append({ 'section': section, 'id': email, 'first_name': first_name, 'last_name': last_name, 'program': program })

print("Total number of students: %d." % len(ALL_STUDENTS))
for section in SECTIONS:
    students_in_section = [s for s in ALL_STUDENTS if s['section'] == section]
    print("%d student(s) in %s." % (len(students_in_section), section))
# Out:
# Total number of students: 253.
# 85 student(s) in Section 1.
# 70 student(s) in Section 2.
# 98 student(s) in Section 3.

# %%
ALL_STUDENTS = [s for s in ALL_STUDENTS if s['section'] == 'Section 1']

# %%
import math
import random

MIN_TEAM_SIZE = 6
MAX_TEAM_SIZE = MIN_TEAM_SIZE + 1
NUMBER_OF_TEAMS = math.floor(len(ALL_STUDENTS) / MIN_TEAM_SIZE)
RANDOM = True

ALL_TEAMS = [ 'Team%03d' % k for k in range (1, NUMBER_OF_TEAMS+1)]

if RANDOM:
    random.shuffle(ALL_STUDENTS)

# %%
from ortools.linear_solver import pywraplp
solver = pywraplp.Solver('StudentProjectGridCBC', pywraplp.Solver.CBC_MIXED_INTEGER_PROGRAMMING)

matches = {}
for student in ALL_STUDENTS:
    for team in ALL_TEAMS:
        matches[student['id'], team] = solver.IntVar(0, 1, 'matches[%s,%s]' % (student['id'], team))

z = solver.Sum(  1 * matches[student['id'], team]
                 for student in ALL_STUDENTS
                 for team in ALL_TEAMS)

for student in ALL_STUDENTS:
    solver.Add(solver.Sum([matches[student['id'], team] for team in ALL_TEAMS]) == 1)
print("`One team per student` added.")

# Between MIN_TEAM_SIZE and MAX_TEAM_SIZE students per project
for team in ALL_TEAMS:
    solver.Add(solver.Sum([matches[student['id'], team] for student in ALL_STUDENTS]) >= MIN_TEAM_SIZE)
    solver.Add(solver.Sum([matches[student['id'], team] for student in ALL_STUDENTS]) <= MAX_TEAM_SIZE)
print("`Team size added.`")


#  1 < MBA <= 2
for team in ALL_TEAMS:
    solver.Add(solver.Sum([matches[student['id'], team] * (1 if student['program'] == 'MBA' else 0) for student in ALL_STUDENTS]) <= 2)
    solver.Add(solver.Sum([matches[student['id'], team] * (1 if student['program'] == 'MBA' else 0) for student in ALL_STUDENTS]) >= 1)

#  LLM <= 1
for team in ALL_TEAMS:
    solver.Add(solver.Sum([matches[student['id'], team] * (1 if student['program'] == 'LLM' else 0) for student in ALL_STUDENTS]) <= 1)

#  CS <= 2
for team in ALL_TEAMS:
    solver.Add(solver.Sum([matches[student['id'], team] * (1 if student['program'] == 'CS' else 0) for student in ALL_STUDENTS]) <= 2)

# ORIE <= 2
for team in ALL_TEAMS:
    solver.Add(solver.Sum([matches[student['id'], team] * (1 if student['program'] == 'ORIE' else 0) for student in ALL_STUDENTS]) <= 2)

# Jacobs <= 2
for team in ALL_TEAMS:
    solver.Add(solver.Sum([matches[student['id'], team] * (1 if student['program'] in ['CM', 'HT'] else 0) for student in ALL_STUDENTS]) <= 2)

    
# At least one technical student
#for team in ALL_TEAMS:
#    solver.Add(solver.Sum([matches[student['id'], team] * (1 if student['program'] == 'Master of Engineering Programs' else 0) for student in ALL_STUDENTS]) >= 1)


objective = solver.Minimize(z)
solver.Solve()
s = solver.Objective().Value()
print(s)
# Out:
# `One team per student` added.
# `Team size added.`
# 85.0

# %%
BUCKETS = {}
for team in ALL_TEAMS:
    BUCKETS[team] = []

for student in ALL_STUDENTS:
    for team in ALL_TEAMS:
        if int(matches[student['id'], team].SolutionValue()):
            BUCKETS[team].append(student)

for index, team in enumerate(ALL_TEAMS):
    print("%s (%d people)" % (team, len(BUCKETS[team])))
    print('-' * 20)
    for student in BUCKETS[team]:
        email = student['id'] if '@' in student['id'] else "%s@cornell.edu" % student['id']
        print('"%s %s",%s,%s,%s,%s' % (student['first_name'], student['last_name'], email, team, student['section'], student['program']))
    print()
# Out:
# Team001 (6 people)
# --------------------
# "Kibum Byun",kb656@cornell.edu,Team001,Section 1,LLM
# "Gabriel Soares Pena Costa",gs669@cornell.edu,Team001,Section 1,MBA
# "Xinzhuo Sun",xs324@cornell.edu,Team001,Section 1,CS
# "Anthony Bisulco",arb426@cornell.edu,Team001,Section 1,ECE
# "Haojie Zhang",hz538@cornell.edu,Team001,Section 1,ORIE
# "Chenyu Zhang",cz442@cornell.edu,Team001,Section 1,CS
#
# Team002 (6 people)
# --------------------
# "Yuchen Shi",ys838@cornell.edu,Team002,Section 1,CM
# "Jillian Burns",jjb427@cornell.edu,Team002,Section 1,CS
# "Natalie Chyi",nhc36@cornell.edu,Team002,Section 1,LLM
# "Alana Lipson",ajl336@cornell.edu,Team002,Section 1,MBA
# "Rahul Naryani",rsn53@cornell.edu,Team002,Section 1,MBA
# "Kulvinder Lotay",ksl76@cornell.edu,Team002,Section 1,CS
#
# Team003 (6 people)
# --------------------
# "Young Sang Choi",yc2376@cornell.edu,Team003,Section 1,HT
# "Yaohai Xu",yx432@cornell.edu,Team003,Section 1,CS
# "Pooja Kale",pk576@cornell.edu,Team003,Section 1,CS
# "Saniya Shah",ss3734@cornell.edu,Team003,Section 1,MBA
# "Owen Daw",od82@cornell.edu,Team003,Section 1,ORIE
# "Christopher Caulfield",ctc98@cornell.edu,Team003,Section 1,CM
#
# Team004 (6 people)
# --------------------
# "Dinesh Singh",ds2346@cornell.edu,Team004,Section 1,CS
# "Adam Naor",an577@cornell.edu,Team004,Section 1,MBA
# "Benjamin Hwang",bwh57@cornell.edu,Team004,Section 1,ORIE
# "Devon Bain",dwb264@cornell.edu,Team004,Section 1,CM
# "Hongyun Oh",ho247@cornell.edu,Team004,Section 1,CS
# "Ipsita Basu",ib293@cornell.edu,Team004,Section 1,MBA
#
# Team005 (6 people)
# --------------------
# "Nian Ji",nj282@cornell.edu,Team005,Section 1,ORIE
# "Steffen Baumgarten",stb92@cornell.edu,Team005,Section 1,CS
# "Bryce Frost",bf326@cornell.edu,Team005,Section 1,MBA
# "Yuzhou Wu",yw995@cornell.edu,Team005,Section 1,CS
# "Stanton Burke",spb232@cornell.edu,Team005,Section 1,LLM
# "Ihab Pothiawala",ip235@cornell.edu,Team005,Section 1,MBA
#
# Team006 (6 people)
# --------------------
# "Advaita Patel",asp265@cornell.edu,Team006,Section 1,CS
# "Yiyuan Feng",yf323@cornell.edu,Team006,Section 1,CM
# "Alexa Lempel",al2444@cornell.edu,Team006,Section 1,CS
# "Emily Tseng",et397@cornell.edu,Team006,Section 1,HT
# "Andrew Schaye",ajs676@cornell.edu,Team006,Section 1,MBA
# "Courtney Levering",crl229@cornell.edu,Team006,Section 1,MBA
#
# Team007 (6 people)
# --------------------
# "Brett Leibowitz",bal246@cornell.edu,Team007,Section 1,CM
# "Jake Bass",jab783@cornell.edu,Team007,Section 1,CS
# "Omer Reshef",or75@cornell.edu,Team007,Section 1,MBA
# "Oluseye Bankole",ob97@cornell.edu,Team007,Section 1,HT
# "Mark O'Looney",mo445@cornell.edu,Team007,Section 1,MBA
# "Wei Duan",wd255@cornell.edu,Team007,Section 1,CS
#
# Team008 (6 people)
# --------------------
# "Keith Yu",ky367@cornell.edu,Team008,Section 1,CS
# "Yuemin Niu",yn276@cornell.edu,Team008,Section 1,ORIE
# "Robert Garcia",rng6@cornell.edu,Team008,Section 1,LLM
# "Balaji Kamakoti",bk498@cornell.edu,Team008,Section 1,MBA
# "Calvin So",ccs254@cornell.edu,Team008,Section 1,CS
# "Romane D'Oncieu",rsd229@cornell.edu,Team008,Section 1,ORIE
#
# Team009 (6 people)
# --------------------
# "Kai Seng Choi",kc977@cornell.edu,Team009,Section 1,CS
# "Bennett Norman",bdn29@cornell.edu,Team009,Section 1,CS
# "Amy Jarvis",asj78@cornell.edu,Team009,Section 1,MBA
# "Subhangi Agarwala",sa2265@cornell.edu,Team009,Section 1,CM
# "Dana Leshem",dl939@cornell.edu,Team009,Section 1,LLM
# "Shwetha Anand",sa2249@cornell.edu,Team009,Section 1,ECE
#
# Team010 (6 people)
# --------------------
# "Ziyou Peng",zp32@cornell.edu,Team010,Section 1,MBA
# "Yuekun Wang",yw2222@cornell.edu,Team010,Section 1,ORIE
# "Cyrus Ghazanfar",cg595@cornell.edu,Team010,Section 1,CS
# "Kriti Singh",ks2259@cornell.edu,Team010,Section 1,CM
# "Tuan-Chun Chen",tc674@cornell.edu,Team010,Section 1,CS
# "Dhruv Jain",dj336@cornell.edu,Team010,Section 1,MBA
#
# Team011 (6 people)
# --------------------
# "Marisha Thakker",mbt53@cornell.edu,Team011,Section 1,LLM
# "Caitlin Maguire",cqm6@cornell.edu,Team011,Section 1,MBA
# "Sungseo Park",sp2528@cornell.edu,Team011,Section 1,CS
# "Ran Sun",rs2468@cornell.edu,Team011,Section 1,CM
# "Edward Beman",elb269@cornell.edu,Team011,Section 1,CS
# "Hongsun Kim",hk442@cornell.edu,Team011,Section 1,ORIE
#
# Team012 (6 people)
# --------------------
# "Mohit Chawla",mc2683@cornell.edu,Team012,Section 1,CM
# "Michael Barron",mgb249@cornell.edu,Team012,Section 1,CS
# "Natalia Becerra",nab256@cornell.edu,Team012,Section 1,LLM
# "Alex Shyu",as3825@cornell.edu,Team012,Section 1,ECE
# "Isha Rana",ir253@cornell.edu,Team012,Section 1,MBA
# "Conor Cunningham",cc2697@cornell.edu,Team012,Section 1,CS
#
# Team013 (7 people)
# --------------------
# "Yi Yuan",yy858@cornell.edu,Team013,Section 1,CS
# "Yifang Chen",yc2493@cornell.edu,Team013,Section 1,ORIE
# "Milan Gunasekera",mag445@cornell.edu,Team013,Section 1,ECE
# "Donovan White",drw262@cornell.edu,Team013,Section 1,MBA
# "Jintao Lai",jl3837@cornell.edu,Team013,Section 1,ECE
# "Ran Ji",rj369@cornell.edu,Team013,Section 1,CS
# "Vicente Rotman",vr328@cornell.edu,Team013,Section 1,HT
#
# Team014 (6 people)
# --------------------
# "Akshay Jha",aj545@cornell.edu,Team014,Section 1,CM
# "James Campbell",jmc695@cornell.edu,Team014,Section 1,MBA
# "Disheng ZHENG",dz336@cornell.edu,Team014,Section 1,CM
# "Gabrielle Zandi",gpz4@cornell.edu,Team014,Section 1,MBA
# "Yifan Zhu",yz2527@cornell.edu,Team014,Section 1,CS
# "Buzhou Feng",bf333@cornell.edu,Team014,Section 1,CS
